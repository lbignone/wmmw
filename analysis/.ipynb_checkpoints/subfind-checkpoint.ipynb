# %%
from astropy.cosmology import FlatLambdaCDM

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
from pygadget_utils import scatter_circles

# %%
from pygadget_utils import filter_by_region

# %%
run pygadget

# %%
run rockstar

# %%
basedirs = ["/media/lbignone/simulations/lgzoom/out512",
            "/media/lbignone/simulations/wmmw/R33306/10",
            "/home/lbignone/simulations/wmmw/R33306/11",
            ]

basename = "/snapshot"

nums = [14, 14, 19]

names = [9, 10, 11]

snaps = {}
fofs = {}
subs = {}
pos = {}
FOF = {}

for basedir, num, name in zip(basedirs, nums, names):
    fname = basedir+basename+"_{0:03d}".format(num)
    snaps[name] = Simulation(fname, multiple_files=True)
    
    fofs[name] = Fof(basedir, num)
    
    pos[name] = snaps[name].read_block("pos", "halo")
    
    FOF[name] = pd.DataFrame(fofs[name].groupcm, columns=["x", "y", "z"])

# %%
rock = rockstar_load("/media/lbignone/simulations/lgzoom/out512/", 14)

# %%
halo_id = 33306
dx = 300

x0 = rock.X[halo_id] * 1000.0
y0 = rock.Y[halo_id] * 1000.0
z0 = rock.Z[halo_id] * 1000.0

xc = 0.21261263 * 50.0 * 1000.0
yc = 0.11032846 * 50.0 * 1000.0
zc = 0.84290926 * 50.0 * 1000.0

x02 = fof.groupcm[700][0]
y02 = fof.groupcm[700][1]
z02 = fof.groupcm[700][2]

xmin = x02 - dx
xmax = x02 + dx

ymin = y02 - dx
ymax = y02 + dx

zmin = z02 - dx
zmax = z02 + dx

# %%
FOF = pd.DataFrame(fof.groupcm, columns=["x", "y", "z"])
SUB = pd.DataFrame(sub.subpos, columns=["x", "y", "z"])

FOF['R200'] = pd.Series(sub.halo_r_crit200)
SUB['parent'] = pd.Series(sub.subparenthalo)

# %%
snap_region = pos[(pos.x > xmin) & (pos.y > ymin) & (pos.z > zmin) & (pos.x < xmax) & (pos.y < ymax) & (pos.z < zmax)]
FOF_region = FOF[(FOF.x > xmin) & (FOF.y > ymin) & (FOF.z > zmin) & (FOF.x < xmax) & (FOF.y < ymax) & (FOF.z < zmax)]
SUB_region = SUB[(SUB.x > xmin) & (SUB.y > ymin) & (SUB.z > zmin) & (SUB.x < xmax) & (SUB.y < ymax) & (SUB.z < zmax)]

# %%
plt.figure(figsize=(15, 10))

plt.scatter(snap_region.x, snap_region.y, s=0.01)

scatter_circles(FOF_region.x, FOF_region.y, FOF.R200, linestyle="dashed", c="none", edgecolor="r")

plt.scatter(SUB_region[SUB_region.parent == 700].x, SUB_region[SUB_region.parent == 700].y, c='g')
