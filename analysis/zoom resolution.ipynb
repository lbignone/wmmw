# %%
run pygadget.py

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned OFF

# %%
levels = [10, 11, 12]
halo_mass = []
for level in levels:
    fname = "/media/Seagate Expansion Drive/lbignone/simulations/wmmw/R33306/{0:d}/ics_512_33306_level{0:d}.dat".format(level)
    snap = Simulation(fname, multiple_files=False)
    halo_mass.append(snap.particle_mass["halo"])
    
halo_mass = array(halo_mass)

# %%
halo_mass = halo_mass*1e10

# %%
halo_mass
# Out:
# array([ 10257646.96503757,   1282205.8706297 ,    160275.73382871])

# %%
for mass in [1e10, 1e11, 1e12, 1e13]:
    n = mass/halo_mass
    plt.plot(levels, n, label="Mvir={0:.0e} M_o/h".format(mass))
             
plt.yscale("log")
plt.xlabel("zoom level")
plt.ylabel("particle number")
plt.title("Particle number inside Rvir")

plt.axhline(5e5, linestyle="dashed")
#plt.axhline(165195, linestyle="dashed")

          
plt.legend(loc=0)

plt.savefig("particle_numbers.pdf")

# %%
plt.plot(levels, halo_mass)

plt.yscale("log")
plt.xlabel("zoom level")
plt.ylabel("dm mass [M_o/h]")
plt.title("Mass resolution")

plt.legend(loc=0)

plt.savefig("mass_resolution.pdf")
